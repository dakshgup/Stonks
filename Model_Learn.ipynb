# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
import xgboost as xgb
import numpy as np
import pandas as pd
import os
from numpy import asarray
from numpy import savetxt

# %%
import pandas as pd
import pickle
f = open("/data.pkl", "rb")
data = pickle.load(f)
# now data has the data

# %%
"""
f = "/all_data.csv"

data = pd.read_csv(f)
#data.head()
data["vector"] = data["vector"].str[1:-1]
data["vector"] = data["vector"].str.strip()
data["vector"] = data["vector"].str.replace("  ", " ")    

data["vector"] = data["vector"].str.split(" ")
d2 = pd.DataFrame(data.vector.tolist(), columns=[i for i in range(459)])
"""
# Out:
# '\nf = "/all_data.csv"\n\ndata = pd.read_csv(f)\n#data.head()\ndata["vector"] = data["vector"].str[1:-1]\ndata["vector"] = data["vector"].str.strip()\ndata["vector"] = data["vector"].str.replace("  ", " ")    \n\ndata["vector"] = data["vector"].str.split(" ")\nd2 = pd.DataFrame(data.vector.tolist(), columns=[i for i in range(459)])\n'

# %%
type(data.vector[0])
data = data.reset_index()
lister = [str(i) for i in range(300)]
vec = pd.DataFrame(data.vector.tolist(), columns=lister)
vec.head()
# Out:
#           0         1         2  ...       297       298       299
# 0 -0.221908  0.305615 -0.153798  ... -0.250279  0.032208  0.118947
# 1 -0.117326  0.999795 -0.537247  ... -0.338873 -0.212646  0.942939
# 2 -0.081208  0.426632 -0.098885  ... -0.130822 -0.028837  0.377058
# 3 -0.053780  0.263991 -0.054686  ... -0.068143 -0.029870  0.182117
# 4 -0.261672  1.372322 -0.825148  ... -0.700230 -0.745174  1.637549
#
# [5 rows x 300 columns]

# %%
final_data = data.join(vec)

final_data = final_data.drop(columns=["vector"])
final_data.head()
# Out:
#         index    open   close         0  ...       296       297       298       299
# 0  2020-01-28  324.45  317.69 -0.221908  ... -0.239288 -0.250279  0.032208  0.118947
# 1  2020-01-03  293.79  297.43 -0.117326  ... -0.213157 -0.338873 -0.212646  0.942939
# 2  2020-01-02  297.15  300.35 -0.081208  ...  0.008716 -0.130822 -0.028837  0.377058
# 3  2019-11-19  265.54  266.29 -0.053780  ... -0.112805 -0.068143 -0.029870  0.182117
# 4  2019-11-06  258.74  257.24 -0.261672  ... -0.431351 -0.700230 -0.745174  1.637549
#
# [5 rows x 303 columns]

# %%
"""
import pickle
with open("/final_data.pkl", "wb") as output:
  pickle.dump(final_data, output)
"""
# Out:
# '\nimport pickle\nwith open("/final_data.pkl", "wb") as output:\n  pickle.dump(final_data, output)\n'

# %%
X = final_data[lister]
y = final_data["open"]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)

# %%
model = RandomForestRegressor(criterion='mae')
# model = xgb.XGBRegressor(random_state=1, objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.625,
#                 max_depth = 3, alpha = 10, n_estimators = 10)
model.fit(train_X, train_y)
pred_y = model.predict(val_X)
mean_absolute_error(val_y, pred_y)
# Out:
# 88.10311525255474

# %%
# model = RandomForestRegressor(random_state=1, criterion="mae")
# model.fit(train_X, train_y)
# pred_y = model.predict(val_X)
# mean_absolute_error(val_y, pred_y)


y_real = y
y_all_pred = model.predict(X)

# %%
print(mean_absolute_error(val_y, pred_y))
# Out:
# 88.10311525255474

# %%
predictions_rf = pd.DataFrame(pred_y)
predictions_rf
# Out:
#               0
# 0    370.350257
# 1    383.970993
# 2    457.769850
# 3    158.721100
# 4    154.962587
# ..          ...
# 680  160.362050
# 681  268.986401
# 682  146.888803
# 683  154.459700
# 684  178.386679
#
# [685 rows x 1 columns]

# %%
predictions_rf.to_csv("pred_output.csv")

better_pred = pd.DataFrame(data={"val": y_real, "pred": y_all_pred})
better_pred.to_csv("better_pred.csv")

# %%
pred_y.astype(int)
savetxt('pred_rf.csv', pred_y, delimiter=',')
os.getcwd()
# Out:
# '/content'
